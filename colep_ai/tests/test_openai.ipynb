# %%
import sys
import os
sys.path.insert(0, os.path.abspath("../"))  # adjust if test/ is nested differently

# %%
import os

from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

try:
    response = client.models.list()

    print("API Key is valid")
    print(f"Available models: {len(response.data)}")

except Exception as e:
    print("API Key is invalid or request failed")
    print(e)
# Out:
# API Key is valid
# Available models: 126

# %%
from core.config import settings

# %%
settings.OPENAI_API_KEY.get_secret_value()
# Out:
# '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'

# %%
def get_openai_client() -> OpenAI:
    return OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
openai_client = get_openai_client()

# %%
openai_client
