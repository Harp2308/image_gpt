# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[1]   # COLEPV1
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from colep_ai.retrieval.retriever import search
import anthropic
from colep_ai.generation.generator import generate_answer

client = anthropic.Anthropic()

# %%
query = "How do I turn line O001.O059.1 on and off?"
chunks = search(query, top_k=5)
# Out:
# 2026-07-09 17:23:09 | INFO | httpx._client | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-07-09 17:23:09 | INFO | httpx._client | HTTP Request: GET https://1ecf121c-0910-4a8f-a398-9e0f5c04a378.eu-west-2-0.aws.cloud.qdrant.io:6333 "HTTP/1.1 200 OK"
# 2026-07-09 17:23:10 | INFO | httpx._client | HTTP Request: POST https://1ecf121c-0910-4a8f-a398-9e0f5c04a378.eu-west-2-0.aws.cloud.qdrant.io:6333/collections/colep_page_based_chunks/points/query "HTTP/1.1 400 Bad Request"
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[3], line 2
#       1 query = "How do I turn line O001.O059.1 on and off?"
# ----> 2 chunks = search(query, top_k=5)
#
# File d:\Harpreet Data\1_PROJECTS\Colep_ai\colepV1\colep_ai\retrieval\retriever.py:29, in search(query, top_k, source_file, page_number)
#      26     qdrant_filter = {"must": conditions}
# ...

# %%
chunks
# Out:
# [{'score': 0.3673713,
#   'entry_id': '4',
#   'entry_text': 'Ligar o sistema de verniz exterior, no botão "ON" indicado a figura.',
#   'entry_text_en': 'Turn on the exterior varnish system, at the "ON" button indicated in the figure.',
#   'image_ids': ['page_2_bac6'],
#   'image_description': 'Photo of a control unit with a display screen and buttons, with a button circled in red.',
#   'source_file': 'e1',
#   'page_number': 2,
#   'document_title': 'Ligar e desligar a linha',
#   'document_code': 'O001.O059.1'},
#  {'score': 0.35184413,
#   'entry_id': '11',
#   'entry_text': 'Ligar os transportadores, rodando o botão do geral no sentido dos ponteiros do relógio.',
#   'entry_text_en': 'Turn on the conveyors, turning the main button clockwise.',
#   'image_ids': ['page_3_03e9', 'page_3_2bc4', 'page_3_7cfe'],
# ...

# %%
for r in chunks:
    print(r["score"], r["entry_text_en"],r["image_ids"])
# Out:
# 0.3673713 Turn on the exterior varnish system, at the "ON" button indicated in the figure. ['page_2_bac6']
# 0.35184413 Turn on the conveyors, turning the main button clockwise. ['page_3_03e9', 'page_3_2bc4', 'page_3_7cfe']
# 0.34779537 Turn off the main switch of the line, at the electrical panel. ['page_5_ee98']
# 0.34366244 Turn on the general power to the welding machine, at the button indicated in the figure. ['page_2_e5f0']
# 0.34091786 Turn off the conveyors and turn the main switch button indicated in the figure. ['page_4_380a', 'page_4_5936', 'page_4_b06d']

# %%
# result = generate_answer(query, chunks, client)
# Out:
# 2026-07-09 17:19:08 | INFO | httpx._client | HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2026-07-09 17:19:08 | INFO | colep_ai.generation.generator | Generated answer for query='How do I turn line O001.O059.1 on and off?' using 5 chunks

# %%
# print(result["answer"])
# Out:
# I don't have enough information in the provided context to specifically answer about line **O001.O059.1**. The context does not mention this line identifier by name.
#
# However, based on the available SOP steps, here is what I can share about **turning on and off** general line/equipment operations:
#
# ---
#
# ## ▶️ Turning ON
#
# 1. **Turn on the general power to the welding machine** at the button indicated in the figure.
# *[page 2 | entry 2] — Image: `page_2_e5f0`*
#
# 2. **Turn on the exterior varnish system** at the "ON" button indicated in the figure.
# *[page 2 | entry 4] — Images: `page_2_bac6`*
#
# 3. **Turn on the conveyors** by rotating the main button clockwise.
# *[page 3 | entry 11] — Images: `page_3_03e9`, `page_3_2bc4`, `page_3_7cfe`*
#
# ---
#
# ## ⏹️ Turning OFF
#
# 1. **Turn off the conveyors** by turning the main switch button indicated in the figure.
# *[page 4 | entry 4] — Images: `page_4_380a`, `page_4_5936`, `page_4_b06d`*
#
# ...

# %%
# print("images:", result["used_image_ids"])
# print("sources:", result["sources"])
# Out:
# images: ['page_3_7cfe', 'page_2_bac6', 'page_5_ee98', 'page_3_03e9', 'page_4_b06d', 'page_4_380a', 'page_4_5936', 'page_3_2bc4', 'page_2_e5f0']
# sources: [{'entry_id': '4', 'page_number': 2, 'source_file': 'e1'}, {'entry_id': '11', 'page_number': 3, 'source_file': 'e1'}, {'entry_id': '9', 'page_number': 5, 'source_file': 'e1'}, {'entry_id': '2', 'page_number': 2, 'source_file': 'e1'}, {'entry_id': '4', 'page_number': 4, 'source_file': 'e1'}]
